# %% [markdown]
# #  Basic demonstration of pyMCR
#
# pyMCR is a small package for performing multivariate curve resolution. Currently, it implements a simple alternating least squares method (i.e., MCR-ALS).
#
# MCR-ALS, in general, is a constrained implementation of alternating least squares (ALS) nonnegative matrix factorization (NMF). Historically, other names were used for MCR as well:
# - Self modeling mixture analysis (SMMA)
# - Self modeling curve resolution (SMCR)
#
# Available methods:
# - Regressors:
#     - Ordinary least squares (default)
#     - Non-negatively constrained least squares
#     - Native support for scikit-learn linear model regressors (e.g., LinearRegression, RidgeRegression, Lasso)
# - Constraints
#     - Non-negativity
#     - Normalization
#     - Error metrics / Loss function
#         Mean-squared error
#
# **MCR assumes a system of the form: D = CS^T**
#
# Data that you will provide (hyperspectral context):
#
# `D [n_pixels, n_frequencies]  # Hyperspectral image unraveled in space (2D)`
#
# `initial_spectra [n_components, n_frequencies]  ## S^T in the literature`
#
# OR
#
# `initial_conc [n_pixels, n_components]   ## C in the literature`
#
# If you have an initial estimate of the spectra
#
# `mcrals.fit(D, ST=initial_spectra)`
#
# Otherwise, if you have an initial estimate of the concentrations
#
# `mcrals.fit(D, C=initial_conc)`

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['savefig.dpi'] = 100

# importing pymcr pieces
from pymcr.mcr import McrAls
from pymcr.regressors import OLS, NNLS
from pymcr.constraints import ConstraintNonneg, ConstraintNorm

# from sklearn.linear_model.ridge import Ridge

# %% [markdown]
# # Define model system
#
# ## Initial spectal components

# %%
wn = np.linspace(400,2800,200)

n_components = 3

sp0 = np.exp(-(wn-1200)**2/(2*200**2))
sp1 = np.exp(-(wn-1600)**2/(2*200**2))
sp2 = np.exp(-(wn-2000)**2/(2*200**2))

plt.plot(wn, sp0, label='Spectrum 0')
plt.plot(wn, sp1, label='Spectrum 1')
plt.plot(wn, sp2, label='Spectrum 2')
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.legend(loc='best')
plt.title('Spectral Components')
# Out:
# Text(0.5, 1.0, 'Spectral Components')

# %% [markdown]
# ## Concentration map
#
# Model starts off as 3 2D-Gaussian centered at (x*, y*) with standard deviation R (1 for each component).
#
# The sum to 1 constraint is then enforced.

# %%
x0 = 25
y0 = 25

x1 = 75
y1 = 25

x2 = 50
y2 = 50

R = 20

M=50  # rows (Y)
N= 100  # cols (X)

# Init concentration map
conc = np.zeros((M,N,n_components))

X,Y = np.meshgrid(np.arange(N), np.arange(M))

conc[...,0] = np.exp(-(X-x0)**2/(2*R**2))*np.exp(-(Y-y0)**2/(2*R**2))
conc[...,1] = np.exp(-(X-x1)**2/(2*R**2))*np.exp(-(Y-y1)**2/(2*R**2))
conc[...,2] = np.exp(-(X-x2)**2/(2*R**2))*np.exp(-(Y-y2)**2/(2*R**2))

conc /= conc.sum(axis=-1)[:,:,None]

# Find the maximum concentration (per component)
# and set to conc = 1 (and make the rest 0's)
# This just ensures that each component has a pure
# pixel somewhere within the image
for num in range(n_components):
    idx = np.unravel_index(conc[...,num].argmax(), conc[...,num].shape)
    tmp = np.zeros(3)
    tmp[num] = 1
    conc[idx[0],idx[1],:] = 1*tmp

plt.figure(figsize=(6,4))
for num in range(3):
    plt.subplot(2,2,num+1)
    plt.imshow(conc[...,num])
    plt.colorbar()
    plt.axis('off')
    plt.title('Component {}'.format(num))

plt.subplot(2,2,4)
plt.imshow(conc.sum(axis=-1))
plt.colorbar()
plt.axis('off')
plt.title('Sum of Conc\'s')
plt.tight_layout()

# %%
# Stack 3 spectral vectors into 1 matrix
spectra = np.vstack((sp0, sp1, sp2))

# Hyperspectral image (HSI)
hsi = np.dot(conc, spectra)

# %% [markdown]
# # Perform MCR-ALS
#
# ## With spectral guess

# %%
# Poor guess
initial_spectra = spectra*wn

plt.figure(figsize=(4,6))
plt.subplot(211)
plt.plot(wn, spectra.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Actual')

plt.subplot(212)
plt.plot(wn, initial_spectra.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Initial Guess')

plt.tight_layout()

# %% [markdown]
# # Preparing PyMCR fit
#
# ## Manual ordering and selection of constraints
#
# Constrains are imported from pymcr.constraints
#
# - ConstraintNonneg is a non-negativity constraint. All negative entries made 0.
#
# - ConstraintNorm is  a normalization constraint, i.e. everything sums to unity.
#
# ## Regressor selection
#
# Different regressor can be selected for calculating the C matrix (c_reg) or the S^T matrix (st_regr).
#
# In the following, we initiate a McrAls object with a st_regr setup with NNLS and c_reg to OLS. One can select regressor with a string, or can import the class and instanstiate.

# %%
print(hsi.shape)
hsi.reshape((-1, wn.size)).shape
# Out:
# (50, 100, 200)
# (5000, 200)

# %%
mcrals = McrAls(max_iter=100, st_regr='NNLS', c_regr=OLS(), 
                c_constraints=[ConstraintNonneg(), ConstraintNorm()])

mcrals.fit(hsi.reshape((-1, wn.size)), ST=initial_spectra, verbose=True)
print('\nFinal MSE: {:.7e}'.format(mcrals.err[-1]))
# Out:
# Iter: 1 (C)	mse: 2.3181e+05
# Iter: 1 (ST)	mse: 3.2199e-04
# Iter: 2 (C)	mse: 1.5935e-04
# Iter: 2 (ST)	mse: 9.4332e-05
# Iter: 3 (C)	mse: 6.4088e-05
# Iter: 3 (ST)	mse: 4.4970e-05
# Iter: 4 (C)	mse: 3.4988e-05
# Iter: 4 (ST)	mse: 2.7080e-05
# Iter: 5 (C)	mse: 2.2584e-05
# Iter: 5 (ST)	mse: 1.8471e-05
# Iter: 6 (C)	mse: 1.5972e-05
# Iter: 6 (ST)	mse: 1.3516e-05
# Iter: 7 (C)	mse: 1.1947e-05
# Iter: 7 (ST)	mse: 1.0344e-05
# Iter: 8 (C)	mse: 9.2744e-06
# Iter: 8 (ST)	mse: 8.1643e-06
# Iter: 9 (C)	mse: 7.3999e-06
# Iter: 9 (ST)	mse: 6.5963e-06
# Iter: 10 (C)	mse: 6.0289e-06
# Iter: 10 (ST)	mse: 5.4282e-06
# Iter: 11 (C)	mse: 4.9948e-06
# Iter: 11 (ST)	mse: 4.5337e-06
# Iter: 12 (C)	mse: 4.1975e-06
# Iter: 12 (ST)	mse: 3.8356e-06
# Iter: 13 (C)	mse: 3.5684e-06
# Iter: 13 (ST)	mse: 3.2790e-06
# Iter: 14 (C)	mse: 3.0648e-06
# Iter: 14 (ST)	mse: 2.8308e-06
# Iter: 15 (C)	mse: 2.6570e-06
# Iter: 15 (ST)	mse: 2.4640e-06
# Iter: 16 (C)	mse: 2.3209e-06
# Iter: 16 (ST)	mse: 2.1604e-06
# Iter: 17 (C)	mse: 2.0422e-06
# Iter: 17 (ST)	mse: 1.9080e-06
# Iter: 18 (C)	mse: 1.8095e-06
# Iter: 18 (ST)	mse: 1.6955e-06
# Iter: 19 (C)	mse: 1.6125e-06
# Iter: 19 (ST)	mse: 1.5150e-06
# Iter: 20 (C)	mse: 1.4450e-06
# Iter: 20 (ST)	mse: 1.3612e-06
# Iter: 21 (C)	mse: 1.3016e-06
# Iter: 21 (ST)	mse: 1.2290e-06
# Iter: 22 (C)	mse: 1.1772e-06
# Iter: 22 (ST)	mse: 1.1140e-06
# Iter: 23 (C)	mse: 1.0688e-06
# Iter: 23 (ST)	mse: 1.0135e-06
# Iter: 24 (C)	mse: 9.7400e-07
# Iter: 24 (ST)	mse: 9.2532e-07
# Iter: 25 (C)	mse: 8.9062e-07
# Iter: 25 (ST)	mse: 8.4765e-07
# Iter: 26 (C)	mse: 8.1691e-07
# Iter: 26 (ST)	mse: 7.7873e-07
# Iter: 27 (C)	mse: 7.5140e-07
# Iter: 27 (ST)	mse: 7.1741e-07
# Iter: 28 (C)	mse: 6.9303e-07
# Iter: 28 (ST)	mse: 6.6272e-07
# Iter: 29 (C)	mse: 6.4095e-07
# Iter: 29 (ST)	mse: 6.1386e-07
# Iter: 30 (C)	mse: 5.9444e-07
# Iter: 30 (ST)	mse: 5.7005e-07
# Iter: 31 (C)	mse: 5.5255e-07
# Iter: 31 (ST)	mse: 5.3050e-07
# Iter: 32 (C)	mse: 5.1465e-07
# Iter: 32 (ST)	mse: 4.9465e-07
# Iter: 33 (C)	mse: 4.8026e-07
# Iter: 33 (ST)	mse: 4.6212e-07
# Iter: 34 (C)	mse: 4.4905e-07
# Iter: 34 (ST)	mse: 4.3260e-07
# Iter: 35 (C)	mse: 4.2072e-07
# Iter: 35 (ST)	mse: 4.0579e-07
# Iter: 36 (C)	mse: 3.9502e-07
# Iter: 36 (ST)	mse: 3.8141e-07
# Iter: 37 (C)	mse: 3.7156e-07
# Iter: 37 (ST)	mse: 3.5909e-07
# Iter: 38 (C)	mse: 3.5004e-07
# Iter: 38 (ST)	mse: 3.3856e-07
# Iter: 39 (C)	mse: 3.3030e-07
# Iter: 39 (ST)	mse: 3.1972e-07
# Iter: 40 (C)	mse: 3.1212e-07
# Iter: 40 (ST)	mse: 3.0238e-07
# Iter: 41 (C)	mse: 2.9537e-07
# Iter: 41 (ST)	mse: 2.8640e-07
# Iter: 42 (C)	mse: 2.7995e-07
# Iter: 42 (ST)	mse: 2.7168e-07
# Iter: 43 (C)	mse: 2.6573e-07
# Iter: 43 (ST)	mse: 2.5807e-07
# Iter: 44 (C)	mse: 2.5257e-07
# Iter: 44 (ST)	mse: 2.4547e-07
# Iter: 45 (C)	mse: 2.4035e-07
# Iter: 45 (ST)	mse: 2.3374e-07
# Iter: 46 (C)	mse: 2.2896e-07
# Iter: 46 (ST)	mse: 2.2282e-07
# Iter: 47 (C)	mse: 2.1836e-07
# Iter: 47 (ST)	mse: 2.1264e-07
# Iter: 48 (C)	mse: 2.0849e-07
# Iter: 48 (ST)	mse: 2.0316e-07
# Iter: 49 (C)	mse: 1.9929e-07
# Iter: 49 (ST)	mse: 1.9433e-07
# Iter: 50 (C)	mse: 1.9072e-07
# Iter: 50 (ST)	mse: 1.8609e-07
# Iter: 51 (C)	mse: 1.8273e-07
# Iter: 51 (ST)	mse: 1.7838e-07
# Iter: 52 (C)	mse: 1.7524e-07
# Iter: 52 (ST)	mse: 1.7116e-07
# Iter: 53 (C)	mse: 1.6821e-07
# Iter: 53 (ST)	mse: 1.6438e-07
# Iter: 54 (C)	mse: 1.6160e-07
# Iter: 54 (ST)	mse: 1.5800e-07
# Iter: 55 (C)	mse: 1.5538e-07
# Iter: 55 (ST)	mse: 1.5198e-07
# Iter: 56 (C)	mse: 1.4950e-07
# Iter: 56 (ST)	mse: 1.4630e-07
# Iter: 57 (C)	mse: 1.4397e-07
# Iter: 57 (ST)	mse: 1.4095e-07
# Iter: 58 (C)	mse: 1.3875e-07
# Iter: 58 (ST)	mse: 1.3590e-07
# Iter: 59 (C)	mse: 1.3383e-07
# Iter: 59 (ST)	mse: 1.3115e-07
# Iter: 60 (C)	mse: 1.2919e-07
# Iter: 60 (ST)	mse: 1.2666e-07
# Iter: 61 (C)	mse: 1.2481e-07
# Iter: 61 (ST)	mse: 1.2243e-07
# Iter: 62 (C)	mse: 1.2069e-07
# Iter: 62 (ST)	mse: 1.1843e-07
# Iter: 63 (C)	mse: 1.1678e-07
# Iter: 63 (ST)	mse: 1.1464e-07
# Iter: 64 (C)	mse: 1.1307e-07
# Iter: 64 (ST)	mse: 1.1105e-07
# Iter: 65 (C)	mse: 1.0956e-07
# Iter: 65 (ST)	mse: 1.0763e-07
# Iter: 66 (C)	mse: 1.0622e-07
# Iter: 66 (ST)	mse: 1.0439e-07
# Iter: 67 (C)	mse: 1.0304e-07
# Iter: 67 (ST)	mse: 1.0130e-07
# Iter: 68 (C)	mse: 1.0001e-07
# Iter: 68 (ST)	mse: 9.8349e-08
# Iter: 69 (C)	mse: 9.7125e-08
# Iter: 69 (ST)	mse: 9.5542e-08
# Iter: 70 (C)	mse: 9.4375e-08
# Iter: 70 (ST)	mse: 9.2868e-08
# Iter: 71 (C)	mse: 9.1755e-08
# Iter: 71 (ST)	mse: 9.0319e-08
# Iter: 72 (C)	mse: 8.9259e-08
# Iter: 72 (ST)	mse: 8.7891e-08
# Iter: 73 (C)	mse: 8.6881e-08
# Iter: 73 (ST)	mse: 8.5577e-08
# Iter: 74 (C)	mse: 8.4615e-08
# Iter: 74 (ST)	mse: 8.3372e-08
# Iter: 75 (C)	mse: 8.2456e-08
# Iter: 75 (ST)	mse: 8.1268e-08
# Iter: 76 (C)	mse: 8.0392e-08
# Iter: 76 (ST)	mse: 7.9255e-08
# Iter: 77 (C)	mse: 7.8417e-08
# Iter: 77 (ST)	mse: 7.7327e-08
# Iter: 78 (C)	mse: 7.6523e-08
# Iter: 78 (ST)	mse: 7.5479e-08
# Iter: 79 (C)	mse: 7.4708e-08
# Iter: 79 (ST)	mse: 7.3707e-08
# Iter: 80 (C)	mse: 7.2967e-08
# Iter: 80 (ST)	mse: 7.2006e-08
# Iter: 81 (C)	mse: 7.1294e-08
# Iter: 81 (ST)	mse: 7.0372e-08
# Iter: 82 (C)	mse: 6.9688e-08
# Iter: 82 (ST)	mse: 6.8802e-08
# Iter: 83 (C)	mse: 6.8144e-08
# Iter: 83 (ST)	mse: 6.7294e-08
# Iter: 84 (C)	mse: 6.6661e-08
# Iter: 84 (ST)	mse: 6.5844e-08
# Iter: 85 (C)	mse: 6.5237e-08
# Iter: 85 (ST)	mse: 6.4452e-08
# Iter: 86 (C)	mse: 6.3868e-08
# Iter: 86 (ST)	mse: 6.3114e-08
# Iter: 87 (C)	mse: 6.2553e-08
# Iter: 87 (ST)	mse: 6.1829e-08
# Iter: 88 (C)	mse: 6.1289e-08
# Iter: 88 (ST)	mse: 6.0594e-08
# Iter: 89 (C)	mse: 6.0075e-08
# Iter: 89 (ST)	mse: 5.9408e-08
# Iter: 90 (C)	mse: 5.8909e-08
# Iter: 90 (ST)	mse: 5.8268e-08
# Iter: 91 (C)	mse: 5.7789e-08
# Iter: 91 (ST)	mse: 5.7173e-08
# Iter: 92 (C)	mse: 5.6713e-08
# Iter: 92 (ST)	mse: 5.6120e-08
# Iter: 93 (C)	mse: 5.5677e-08
# Iter: 93 (ST)	mse: 5.5105e-08
# Iter: 94 (C)	mse: 5.4679e-08
# Iter: 94 (ST)	mse: 5.4126e-08
# Iter: 95 (C)	mse: 5.3714e-08
# Iter: 95 (ST)	mse: 5.3179e-08
# Iter: 96 (C)	mse: 5.2781e-08
# Iter: 96 (ST)	mse: 5.2264e-08
# Iter: 97 (C)	mse: 5.1878e-08
# Iter: 97 (ST)	mse: 5.1378e-08
# Iter: 98 (C)	mse: 5.1005e-08
# Iter: 98 (ST)	mse: 5.0520e-08
# Iter: 99 (C)	mse: 5.0159e-08
# Iter: 99 (ST)	mse: 4.9689e-08
# Iter: 100 (C)	mse: 4.9339e-08
# Iter: 100 (ST)	mse: 4.8884e-08
# Max iterations reached (100).
#
# Final MSE: 4.8883896e-08

# %% [markdown]
# # Plotting the results

# %%
plt.figure(figsize=(6,4))
plt.subplot(221)
plt.plot(wn, initial_spectra.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Initial Guess')

plt.subplot(222)
plt.plot(wn, spectra.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Actual')

plt.subplot(223)
plt.plot(wn, mcrals.ST_opt_.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('MCR-ALS Retrieved')

plt.subplot(224)
plt.plot(wn, spectra.T - mcrals.ST_opt_.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Difference')

plt.tight_layout()
plt.savefig('mcr_spectra_retr.png')
plt.show()

temp = mcrals.C_opt_.reshape(conc.shape)
plt.figure(figsize=(6,4))
for num in range(n_components):
    plt.subplot(3,3,3*num+1)
    plt.imshow(conc[...,num])
    plt.colorbar()
    plt.axis('off')
    
    plt.title('Real')

    plt.subplot(3,3,3*num+2)
    plt.imshow(temp[...,num])
    plt.colorbar()
    plt.axis('off')

    if num == 0:
        plt.title('Retrieved')

    plt.subplot(3,3,3*num+3)
    plt.imshow(conc[...,num] - temp[...,num], cmap='seismic')
    plt.colorbar()
    plt.axis('off')

    plt.title('Difference')

plt.tight_layout()
plt.savefig('mcr_conc_retr.png')
plt.show()

# %% [markdown]
# ## With concentration guess
#
# We initiate a poor guess of concentrations to be used by AlsMcr

# %%
# Poor guess
initial_conc = np.zeros((M,N,3))
initial_conc[...,0] = np.dot(np.ones(M)[:,None], (np.arange(N,0,-1)/N)[None,:])
initial_conc[...,1] = np.dot(np.ones(M)[:,None], (np.arange(N)/N)[None,:])
initial_conc[...,2] = np.dot((np.arange(M)/M)[:,None], np.ones(N)[None,:])
initial_conc += np.random.rand(M,N,3)

plt.figure(figsize=(6,4))
for num in range(n_components):
    plt.subplot(3,3,3*num+1)
    plt.imshow(conc[...,num])
    plt.colorbar()
    plt.axis('off')
    if num == 0:
        plt.title('Real')

    plt.subplot(3,3,3*num+2)
    plt.imshow(initial_conc[...,num])
    plt.colorbar()
    plt.axis('off')
    if num == 0:
        plt.title('Guess')
plt.tight_layout()

# %% [markdown]
# ## Performing the fit
#
# c_regre and st_regr are setup to NNLS, constrains are activated.

# %%
mcrals = McrAls(max_iter=100, tol_increase=2,c_regr='NNLS',
                st_regr='NNLS', c_constraints=[ConstraintNonneg(), ConstraintNorm()])

mcrals.fit(hsi.reshape((-1, wn.size)), C=initial_conc.reshape((M*N,n_components)),
           verbose=True)
print('\nFinal MSE: {:.7e}'.format(mcrals.err[-1]))
# Out:
# Iter: 1 (ST)	mse: 1.7193e-02
# Iter: 2 (C)	mse: 4.5428e-02
# Iter: 2 (ST)	mse: 9.7755e-04
# Iter: 3 (C)	mse: 4.3180e-04
# Iter: 3 (ST)	mse: 1.7201e-04
# Iter: 4 (C)	mse: 1.3189e-04
# Iter: 4 (ST)	mse: 7.1164e-05
# Iter: 5 (C)	mse: 6.1400e-05
# Iter: 5 (ST)	mse: 3.9084e-05
# Iter: 6 (C)	mse: 3.5413e-05
# Iter: 6 (ST)	mse: 2.5200e-05
# Iter: 7 (C)	mse: 2.3400e-05
# Iter: 7 (ST)	mse: 1.7995e-05
# Iter: 8 (C)	mse: 1.6950e-05
# Iter: 8 (ST)	mse: 1.3785e-05
# Iter: 9 (C)	mse: 1.3110e-05
# Iter: 9 (ST)	mse: 1.1117e-05
# Iter: 10 (C)	mse: 1.0651e-05
# Iter: 10 (ST)	mse: 9.3290e-06
# Iter: 11 (C)	mse: 8.9917e-06
# Iter: 11 (ST)	mse: 8.0683e-06
# Iter: 12 (C)	mse: 7.8131e-06
# Iter: 12 (ST)	mse: 7.1438e-06
# Iter: 13 (C)	mse: 6.9431e-06
# Iter: 13 (ST)	mse: 6.4405e-06
# Iter: 14 (C)	mse: 6.2760e-06
# Iter: 14 (ST)	mse: 5.8830e-06
# Iter: 15 (C)	mse: 5.7435e-06
# Iter: 15 (ST)	mse: 5.4295e-06
# Iter: 16 (C)	mse: 5.3089e-06
# Iter: 16 (ST)	mse: 5.0503e-06
# Iter: 17 (C)	mse: 4.9436e-06
# Iter: 17 (ST)	mse: 4.7259e-06
# Iter: 18 (C)	mse: 4.6297e-06
# Iter: 18 (ST)	mse: 4.4432e-06
# Iter: 19 (C)	mse: 4.3558e-06
# Iter: 19 (ST)	mse: 4.1933e-06
# Iter: 20 (C)	mse: 4.1135e-06
# Iter: 20 (ST)	mse: 3.9700e-06
# Iter: 21 (C)	mse: 3.8966e-06
# Iter: 21 (ST)	mse: 3.7689e-06
# Iter: 22 (C)	mse: 3.7009e-06
# Iter: 22 (ST)	mse: 3.5866e-06
# Iter: 23 (C)	mse: 3.5236e-06
# Iter: 23 (ST)	mse: 3.4202e-06
# Iter: 24 (C)	mse: 3.3618e-06
# Iter: 24 (ST)	mse: 3.2677e-06
# Iter: 25 (C)	mse: 3.2133e-06
# Iter: 25 (ST)	mse: 3.1272e-06
# Iter: 26 (C)	mse: 3.0765e-06
# Iter: 26 (ST)	mse: 2.9974e-06
# Iter: 27 (C)	mse: 2.9500e-06
# Iter: 27 (ST)	mse: 2.8771e-06
# Iter: 28 (C)	mse: 2.8328e-06
# Iter: 28 (ST)	mse: 2.7655e-06
# Iter: 29 (C)	mse: 2.7241e-06
# Iter: 29 (ST)	mse: 2.6618e-06
# Iter: 30 (C)	mse: 2.6230e-06
# Iter: 30 (ST)	mse: 2.5652e-06
# Iter: 31 (C)	mse: 2.5288e-06
# Iter: 31 (ST)	mse: 2.4751e-06
# Iter: 32 (C)	mse: 2.4409e-06
# Iter: 32 (ST)	mse: 2.3908e-06
# Iter: 33 (C)	mse: 2.3587e-06
# Iter: 33 (ST)	mse: 2.3117e-06
# Iter: 34 (C)	mse: 2.2814e-06
# Iter: 34 (ST)	mse: 2.2374e-06
# Iter: 35 (C)	mse: 2.2088e-06
# Iter: 35 (ST)	mse: 2.1675e-06
# Iter: 36 (C)	mse: 2.1405e-06
# Iter: 36 (ST)	mse: 2.1016e-06
# Iter: 37 (C)	mse: 2.0762e-06
# Iter: 37 (ST)	mse: 2.0396e-06
# Iter: 38 (C)	mse: 2.0155e-06
# Iter: 38 (ST)	mse: 1.9810e-06
# Iter: 39 (C)	mse: 1.9583e-06
# Iter: 39 (ST)	mse: 1.9257e-06
# Iter: 40 (C)	mse: 1.9041e-06
# Iter: 40 (ST)	mse: 1.8733e-06
# Iter: 41 (C)	mse: 1.8528e-06
# Iter: 41 (ST)	mse: 1.8237e-06
# Iter: 42 (C)	mse: 1.8042e-06
# Iter: 42 (ST)	mse: 1.7767e-06
# Iter: 43 (C)	mse: 1.7581e-06
# Iter: 43 (ST)	mse: 1.7320e-06
# Iter: 44 (C)	mse: 1.7144e-06
# Iter: 44 (ST)	mse: 1.6896e-06
# Iter: 45 (C)	mse: 1.6728e-06
# Iter: 45 (ST)	mse: 1.6492e-06
# Iter: 46 (C)	mse: 1.6332e-06
# Iter: 46 (ST)	mse: 1.6108e-06
# Iter: 47 (C)	mse: 1.5956e-06
# Iter: 47 (ST)	mse: 1.5742e-06
# Iter: 48 (C)	mse: 1.5596e-06
# Iter: 48 (ST)	mse: 1.5392e-06
# Iter: 49 (C)	mse: 1.5253e-06
# Iter: 49 (ST)	mse: 1.5058e-06
# Iter: 50 (C)	mse: 1.4925e-06
# Iter: 50 (ST)	mse: 1.4738e-06
# Iter: 51 (C)	mse: 1.4610e-06
# Iter: 51 (ST)	mse: 1.4432e-06
# Iter: 52 (C)	mse: 1.4309e-06
# Iter: 52 (ST)	mse: 1.4139e-06
# Iter: 53 (C)	mse: 1.4021e-06
# Iter: 53 (ST)	mse: 1.3857e-06
# Iter: 54 (C)	mse: 1.3744e-06
# Iter: 54 (ST)	mse: 1.3588e-06
# Iter: 55 (C)	mse: 1.3479e-06
# Iter: 55 (ST)	mse: 1.3329e-06
# Iter: 56 (C)	mse: 1.3225e-06
# Iter: 56 (ST)	mse: 1.3081e-06
# Iter: 57 (C)	mse: 1.2980e-06
# Iter: 57 (ST)	mse: 1.2842e-06
# Iter: 58 (C)	mse: 1.2745e-06
# Iter: 58 (ST)	mse: 1.2612e-06
# Iter: 59 (C)	mse: 1.2519e-06
# Iter: 59 (ST)	mse: 1.2391e-06
# Iter: 60 (C)	mse: 1.2301e-06
# Iter: 60 (ST)	mse: 1.2178e-06
# Iter: 61 (C)	mse: 1.2092e-06
# Iter: 61 (ST)	mse: 1.1973e-06
# Iter: 62 (C)	mse: 1.1889e-06
# Iter: 62 (ST)	mse: 1.1775e-06
# Iter: 63 (C)	mse: 1.1694e-06
# Iter: 63 (ST)	mse: 1.1584e-06
# Iter: 64 (C)	mse: 1.1506e-06
# Iter: 64 (ST)	mse: 1.1400e-06
# Iter: 65 (C)	mse: 1.1324e-06
# Iter: 65 (ST)	mse: 1.1222e-06
# Iter: 66 (C)	mse: 1.1149e-06
# Iter: 66 (ST)	mse: 1.1050e-06
# Iter: 67 (C)	mse: 1.0979e-06
# Iter: 67 (ST)	mse: 1.0883e-06
# Iter: 68 (C)	mse: 1.0815e-06
# Iter: 68 (ST)	mse: 1.0722e-06
# Iter: 69 (C)	mse: 1.0656e-06
# Iter: 69 (ST)	mse: 1.0566e-06
# Iter: 70 (C)	mse: 1.0502e-06
# Iter: 70 (ST)	mse: 1.0416e-06
# Iter: 71 (C)	mse: 1.0353e-06
# Iter: 71 (ST)	mse: 1.0269e-06
# Iter: 72 (C)	mse: 1.0209e-06
# Iter: 72 (ST)	mse: 1.0127e-06
# Iter: 73 (C)	mse: 1.0068e-06
# Iter: 73 (ST)	mse: 9.9891e-07
# Iter: 74 (C)	mse: 9.9320e-07
# Iter: 74 (ST)	mse: 9.8551e-07
# Iter: 75 (C)	mse: 9.7996e-07
# Iter: 75 (ST)	mse: 9.7250e-07
# Iter: 76 (C)	mse: 9.6711e-07
# Iter: 76 (ST)	mse: 9.5985e-07
# Iter: 77 (C)	mse: 9.5461e-07
# Iter: 77 (ST)	mse: 9.4756e-07
# Iter: 78 (C)	mse: 9.4246e-07
# Iter: 78 (ST)	mse: 9.3561e-07
# Iter: 79 (C)	mse: 9.3064e-07
# Iter: 79 (ST)	mse: 9.2398e-07
# Iter: 80 (C)	mse: 9.1915e-07
# Iter: 80 (ST)	mse: 9.1266e-07
# Iter: 81 (C)	mse: 9.0795e-07
# Iter: 81 (ST)	mse: 9.0165e-07
# Iter: 82 (C)	mse: 8.9705e-07
# Iter: 82 (ST)	mse: 8.9092e-07
# Iter: 83 (C)	mse: 8.8644e-07
# Iter: 83 (ST)	mse: 8.8047e-07
# Iter: 84 (C)	mse: 8.7611e-07
# Iter: 84 (ST)	mse: 8.7030e-07
# Iter: 85 (C)	mse: 8.6603e-07
# Iter: 85 (ST)	mse: 8.6038e-07
# Iter: 86 (C)	mse: 8.5621e-07
# Iter: 86 (ST)	mse: 8.5070e-07
# Iter: 87 (C)	mse: 8.4664e-07
# Iter: 87 (ST)	mse: 8.4127e-07
# Iter: 88 (C)	mse: 8.3730e-07
# Iter: 88 (ST)	mse: 8.3206e-07
# Iter: 89 (C)	mse: 8.2818e-07
# Iter: 89 (ST)	mse: 8.2307e-07
# Iter: 90 (C)	mse: 8.1928e-07
# Iter: 90 (ST)	mse: 8.1429e-07
# Iter: 91 (C)	mse: 8.1059e-07
# Iter: 91 (ST)	mse: 8.0572e-07
# Iter: 92 (C)	mse: 8.0209e-07
# Iter: 92 (ST)	mse: 7.9734e-07
# Iter: 93 (C)	mse: 7.9379e-07
# Iter: 93 (ST)	mse: 7.8915e-07
# Iter: 94 (C)	mse: 7.8568e-07
# Iter: 94 (ST)	mse: 7.8114e-07
# Iter: 95 (C)	mse: 7.7774e-07
# Iter: 95 (ST)	mse: 7.7330e-07
# Iter: 96 (C)	mse: 7.6998e-07
# Iter: 96 (ST)	mse: 7.6563e-07
# Iter: 97 (C)	mse: 7.6238e-07
# Iter: 97 (ST)	mse: 7.5812e-07
# Iter: 98 (C)	mse: 7.5494e-07
# Iter: 98 (ST)	mse: 7.5077e-07
# Iter: 99 (C)	mse: 7.4765e-07
# Iter: 99 (ST)	mse: 7.4357e-07
# Iter: 100 (C)	mse: 7.4051e-07
# Iter: 100 (ST)	mse: 7.3651e-07
# Max iterations reached (100).
#
# Final MSE: 7.3651182e-07

# %%
# Plotting the results

# %%
plt.figure(figsize=(4,6))
plt.subplot(311)
plt.plot(wn, spectra.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Actual')

plt.subplot(312)
plt.plot(wn, mcrals.ST_opt_.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('MCR-ALS Retrieved')

plt.subplot(313)
plt.plot(wn, spectra.T - mcrals.ST_opt_.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Difference')

plt.tight_layout()
plt.show()

temp = mcrals.C_opt_.reshape(conc.shape)
plt.figure(figsize=(6,4))
for num in range(n_components):
    plt.subplot(3,3,3*num+1)
    plt.imshow(conc[...,num])
    plt.colorbar()
    plt.axis('off')
    if num == 0:
        plt.title('Real')

    plt.subplot(3,3,3*num+2)
    plt.imshow(temp[...,num])
    plt.colorbar()
    plt.axis('off')

    if num == 0:
        plt.title('Retrieved')

    plt.subplot(3,3,3*num+3)
    plt.imshow(conc[...,num] - temp[...,num], cmap='seismic')
    plt.colorbar()
    plt.axis('off')

    if num == 0:
        plt.title('Difference')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Using external regressors
#
# ## Scikit-Learn Ridge Regression
#
# It is possible to use an external regressor from scikit learn to perform the fit, instead of using the provided OLS or NNLS algoritm.
#
# The regressor should be initialised and provided to the c_regr and st_regr functions.

# %%
mcrals = McrAls(max_iter=100, tol_increase=2, tol_err_change=1e-10,
                c_regr=Ridge(alpha=1), st_regr=NNLS(), 
                c_constraints=[ConstraintNonneg(), ConstraintNorm()])

mcrals.fit(hsi.reshape((-1, wn.size)), ST=initial_spectra, verbose=True)
print('\nFinal MSE: {:.7e}'.format(mcrals.err[-1]))
# Out:
# Iter: 1 (C)	mse: 2.3251e+05
# Iter: 1 (ST)	mse: 2.9230e-04
# Iter: 2 (C)	mse: 1.6593e-04
# Iter: 2 (ST)	mse: 9.0076e-05
# Iter: 3 (C)	mse: 7.9963e-05
# Iter: 3 (ST)	mse: 6.3138e-05
# Iter: 4 (C)	mse: 6.1943e-05
# Iter: 4 (ST)	mse: 5.4762e-05
# Iter: 5 (C)	mse: 5.5318e-05
# Iter: 5 (ST)	mse: 5.0386e-05
# Iter: 6 (C)	mse: 5.2226e-05
# Iter: 6 (ST)	mse: 4.8065e-05
# Iter: 7 (C)	mse: 4.9456e-05
# Iter: 7 (ST)	mse: 4.5810e-05
# Iter: 8 (C)	mse: 4.6964e-05
# Iter: 8 (ST)	mse: 4.3732e-05
# Iter: 9 (C)	mse: 4.4760e-05
# Iter: 9 (ST)	mse: 4.1870e-05
# Iter: 10 (C)	mse: 4.2819e-05
# Iter: 10 (ST)	mse: 4.0224e-05
# Iter: 11 (C)	mse: 4.1113e-05
# Iter: 11 (ST)	mse: 3.8770e-05
# Iter: 12 (C)	mse: 3.9580e-05
# Iter: 12 (ST)	mse: 3.7461e-05
# Iter: 13 (C)	mse: 3.8195e-05
# Iter: 13 (ST)	mse: 3.6274e-05
# Iter: 14 (C)	mse: 3.6940e-05
# Iter: 14 (ST)	mse: 3.5193e-05
# Iter: 15 (C)	mse: 3.5797e-05
# Iter: 15 (ST)	mse: 3.4204e-05
# Iter: 16 (C)	mse: 3.4759e-05
# Iter: 16 (ST)	mse: 3.3303e-05
# Iter: 17 (C)	mse: 3.3810e-05
# Iter: 17 (ST)	mse: 3.2475e-05
# Iter: 18 (C)	mse: 3.2941e-05
# Iter: 18 (ST)	mse: 3.1715e-05
# Iter: 19 (C)	mse: 3.2146e-05
# Iter: 19 (ST)	mse: 3.1019e-05
# Iter: 20 (C)	mse: 3.1408e-05
# Iter: 20 (ST)	mse: 3.0417e-05
# Iter: 21 (C)	mse: 3.0740e-05
# Iter: 21 (ST)	mse: 2.9914e-05
# Iter: 22 (C)	mse: 3.0168e-05
# Iter: 22 (ST)	mse: 2.9489e-05
# Iter: 23 (C)	mse: 2.9682e-05
# Iter: 23 (ST)	mse: 2.9126e-05
# Iter: 24 (C)	mse: 2.9254e-05
# Iter: 24 (ST)	mse: 2.8799e-05
# Iter: 25 (C)	mse: 2.8875e-05
# Iter: 25 (ST)	mse: 2.8501e-05
# Iter: 26 (C)	mse: 2.8542e-05
# Iter: 26 (ST)	mse: 2.8235e-05
# Iter: 27 (C)	mse: 2.8245e-05
# Iter: 27 (ST)	mse: 2.7993e-05
# Iter: 28 (C)	mse: 2.7975e-05
# Iter: 28 (ST)	mse: 2.7771e-05
# Iter: 29 (C)	mse: 2.7735e-05
# Iter: 29 (ST)	mse: 2.7569e-05
# Iter: 30 (C)	mse: 2.7523e-05
# Iter: 30 (ST)	mse: 2.7389e-05
# Iter: 31 (C)	mse: 2.7337e-05
# Iter: 31 (ST)	mse: 2.7229e-05
# Iter: 32 (C)	mse: 2.7177e-05
# Iter: 32 (ST)	mse: 2.7089e-05
# Iter: 33 (C)	mse: 2.7040e-05
# Iter: 33 (ST)	mse: 2.6969e-05
# Iter: 34 (C)	mse: 2.6924e-05
# Iter: 34 (ST)	mse: 2.6866e-05
# Iter: 35 (C)	mse: 2.6824e-05
# Iter: 35 (ST)	mse: 2.6777e-05
# Iter: 36 (C)	mse: 2.6736e-05
# Iter: 36 (ST)	mse: 2.6698e-05
# Iter: 37 (C)	mse: 2.6660e-05
# Iter: 37 (ST)	mse: 2.6629e-05
# Iter: 38 (C)	mse: 2.6594e-05
# Iter: 38 (ST)	mse: 2.6569e-05
# Iter: 39 (C)	mse: 2.6538e-05
# Iter: 39 (ST)	mse: 2.6517e-05
# Iter: 40 (C)	mse: 2.6490e-05
# Iter: 40 (ST)	mse: 2.6473e-05
# Iter: 41 (C)	mse: 2.6450e-05
# Iter: 41 (ST)	mse: 2.6435e-05
# Iter: 42 (C)	mse: 2.6416e-05
# Iter: 42 (ST)	mse: 2.6404e-05
# Iter: 43 (C)	mse: 2.6388e-05
# Iter: 43 (ST)	mse: 2.6379e-05
# Iter: 44 (C)	mse: 2.6366e-05
# Iter: 44 (ST)	mse: 2.6358e-05
# Iter: 45 (C)	mse: 2.6348e-05
# Iter: 45 (ST)	mse: 2.6341e-05
# Iter: 46 (C)	mse: 2.6333e-05
# Iter: 46 (ST)	mse: 2.6328e-05
# Iter: 47 (C)	mse: 2.6321e-05
# Iter: 47 (ST)	mse: 2.6317e-05
# Iter: 48 (C)	mse: 2.6313e-05
# Iter: 48 (ST)	mse: 2.6309e-05
# Iter: 49 (C)	mse: 2.6306e-05
# Iter: 49 (ST)	mse: 2.6303e-05
# Iter: 50 (C)	mse: 2.6300e-05
# Iter: 50 (ST)	mse: 2.6298e-05
# Iter: 51 (C)	mse: 2.6297e-05
# Iter: 51 (ST)	mse: 2.6295e-05
# Iter: 52 (C)	mse: 2.6294e-05
# Iter: 52 (ST)	mse: 2.6292e-05
# Iter: 53 (C)	mse: 2.6292e-05
# Iter: 53 (ST)	mse: 2.6291e-05
# Iter: 54 (C)	mse: 2.6291e-05
# Iter: 54 (ST)	mse: 2.6290e-05
# Iter: 55 (C)	mse: 2.6290e-05
# Iter: 55 (ST)	mse: 2.6289e-05
# Iter: 56 (C)	mse: 2.6290e-05
# Iter: 56 (ST)	mse: 2.6289e-05
# Iter: 57 (C)	mse: 2.6290e-05
# Iter: 57 (ST)	mse: 2.6289e-05
# Change in err below tol_err_change (4.4557e-11). Exiting.
#
# Final MSE: 2.6289053e-05

# %% [markdown]
# # Plotting the results with sklearn regressor

# %%
plt.figure(figsize=(4,6))
plt.subplot(311)
plt.plot(wn, spectra.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Actual')

plt.subplot(312)
plt.plot(wn, mcrals.ST_opt_.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('MCR-ALS Retrieved')

plt.subplot(313)
plt.plot(wn, spectra.T - mcrals.ST_opt_.T)
plt.xlabel(r'Wavenumber (cm$^{-1}$)')
plt.ylabel('Intensity (au)')
plt.title('Difference')

plt.tight_layout()
plt.show()

temp = mcrals.C_opt_.reshape(conc.shape)
plt.figure(figsize=(6,4))
for num in range(n_components):
    plt.subplot(3,3,3*num+1)
    plt.imshow(conc[...,num])
    plt.colorbar()
    plt.axis('off')
    if num == 0:
        plt.title('Real')

    plt.subplot(3,3,3*num+2)
    plt.imshow(temp[...,num])
    plt.colorbar()
    plt.axis('off')

    if num == 0:
        plt.title('Retrieved')

    plt.subplot(3,3,3*num+3)
    plt.imshow(conc[...,num] - temp[...,num], cmap='seismic')
    plt.colorbar()
    plt.axis('off')

    if num == 0:
        plt.title('Difference')

plt.tight_layout()
plt.show()
